# %% [markdown]
# # Task 2:
# ## Item clustering (Part 2)
#
# **Objetivo del notebook:**

# %% [markdown]
# ### Importación de las principales librerías

# %%
# silence warnings
import warnings
warnings.filterwarnings("ignore")

# operating system
import os

# time calculation to track some processes
import time
from datetime import timedelta

# numeric and matrix operations
import math
import numpy as np
import pandas as pd

# scientific computations library
import scipy as sp

# loading ploting libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# python core library for machine learning and data science
import sklearn
from sklearn import set_config
set_config(transform_output = "pandas")

from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, FunctionTransformer, StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.cluster import KMeans

# import the function to compute cosine_similarity
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Preprocessing para el Clustering

# %%
df_cluster = pd.read_csv("E:/Capstone-Retail/data_dsmarket/task_2_clustering/df_cluster_item_ready_ext.csv") #Marina Windows

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3049 entries, 0 to 3048
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   item                        3049 non-null   object
#  1   item_exhibition_days        3049 non-null   int64
#  2   days_with_purchases         3049 non-null   int64
#  3   purchase_to_exhib_ratio     3049 non-null   float64
#  4   units                       3049 non-null   int64
#  5   revenue                     3049 non-null   float64
#  6   initial_sell_price          3049 non-null   float64
#  7   first_discount              3049 non-null   float64
#  8   days_until_first_discount   3049 non-null   int64
#  9   discount_on_date_days       3049 non-null   int64
#  10  week_sales_%                3049 non-null   float64
#  11  weekend_sales_%             3049 non-null   float64
#  12  summer_sales_%              3049 non-null   float64
#  13  christmas_sales_%           3049 non-null   float64
#  14  event_sales_%               3049 non-null   float64
#  15  event_SuperBowl_sales_%     3049 non-null   float64
#  16  event_Thanksgiving_sales_%  3049 non-null   float64
#  17  event_Ramadan_sales_%       3049 non-null   float64
#  18  event_NewYear_sales_%       3049 non-null   float64
#  19  event_Easter_sales_%        3049 non-null   float64
#  20  discount_on_date_sales_%    3049 non-null   float64
#  21  mean_pvp                    3049 non-null   float64
#  22  units_per_purchase          3049 non-null   float64
#  23  revenue_per_purchase        3049 non-null   float64
#  24  mean_discount               3049 non-null   float64
#  25  2016_vs_2015                3049 non-null   float64
#  26  2015_vs_2014                3048 non-null   float64
#  27  2014_vs_2013                3017 non-null   float64
#  28  category_id                 3049 non-null   int64
#  29  BOS_1_%                     3049 non-null   float64
#  30  BOS_2_%                     3049 non-null   float64
#  31  BOS_3_%                     3049 non-null   float64
#  32  NYC_1_%                     3049 non-null   float64
#  33  NYC_2_%                     3049 non-null   float64
#  34  NYC_3_%                     3049 non-null   float64
#  35  NYC_4_%                     3049 non-null   float64
#  36  PHI_1_%                     3049 non-null   float64
#  37  PHI_2_%                     3049 non-null   float64
#  38  PHI_3_%                     3049 non-null   float64
# dtypes: float64(32), int64(6), object(1)
# memory usage: 929.1+ KB

# %%
df_cluster.isnull().sum().sum()
# Out:
# 33

# %%
df_cluster.isnull().sum()
# Out:
# item                           0
# item_exhibition_days           0
# days_with_purchases            0
# purchase_to_exhib_ratio        0
# units                          0
# revenue                        0
# initial_sell_price             0
# first_discount                 0
# days_until_first_discount      0
# discount_on_date_days          0
# week_sales_%                   0
# weekend_sales_%                0
# summer_sales_%                 0
# christmas_sales_%              0
# event_sales_%                  0
# event_SuperBowl_sales_%        0
# event_Thanksgiving_sales_%     0
# event_Ramadan_sales_%          0
# event_NewYear_sales_%          0
# event_Easter_sales_%           0
# discount_on_date_sales_%       0
# mean_pvp                       0
# units_per_purchase             0
# revenue_per_purchase           0
# mean_discount                  0
# 2016_vs_2015                   0
# 2015_vs_2014                   1
# 2014_vs_2013                  32
# category_id                    0
# BOS_1_%                        0
# BOS_2_%                        0
# BOS_3_%                        0
# NYC_1_%                        0
# NYC_2_%                        0
# NYC_3_%                        0
# NYC_4_%                        0
# PHI_1_%                        0
# PHI_2_%                        0
# PHI_3_%                        0
# dtype: int64

# %%
df_cluster["2015_vs_2014"] = df_cluster.groupby("item")["2015_vs_2014"].fillna(method="ffill").fillna(method="bfill")
df_cluster["2014_vs_2013"] = df_cluster.groupby("item")["2014_vs_2013"].fillna(method="ffill").fillna(method="bfill")

# %%
df_cluster.isnull().sum().sum()
# Out:
# 0

# %%
df_cluster = df_cluster.round(5)
df_cluster.head()
# Out:
#                item  item_exhibition_days  days_with_purchases  \
# 0  ACCESORIES_1_001                  1013                  973
# 1  ACCESORIES_1_002                  1877                 1619
# 2  ACCESORIES_1_003                   807                  597
# 3  ACCESORIES_1_004                  1912                 1900
# 4  ACCESORIES_1_005                  1815                 1765
#
#    purchase_to_exhib_ratio  units    revenue  initial_sell_price  \
# 0                  0.96051   4093   45037.55               12.74
# 1                  0.86255   5059   26676.13                5.28
# 2                  0.73978   1435    5652.09                7.94
# 3                  0.99372  39143  235209.81                6.17
# 4                  0.97245  14621   55555.94                4.10
#
#    first_discount  days_until_first_discount  discount_on_date_days  ...  \
# 0         0.13736                         -1                   2589  ...
# 1         0.25189                       1290                     11  ...
# 2         0.00000                        801                   2729  ...
# 3         0.00000                       1906                   1039  ...
# 4         0.09091                        150                   1573  ...
#
#    BOS_1_%   BOS_2_%   BOS_3_%   NYC_1_%   NYC_2_%   NYC_3_%   NYC_4_%  \
# 0  6.35231   9.82165   9.40630  14.65917  13.24212  18.51942  15.51429
# 1  4.34869   5.93003   7.07650   9.74501   6.48349   8.93457   6.38466
# 2  6.89895   7.03833  12.40418  20.06969  10.10453   9.54704  11.21951
# 3  7.53136   9.09997   8.10873   8.39997  19.14519  26.67654   4.05181
# 4  7.68757  13.78839   6.85316  12.64619  13.94569  18.21353   6.36071
#
#     PHI_1_%   PHI_2_%   PHI_3_%
# 0   4.34889   2.80968   5.32617
# 1  22.59340  15.41807  13.08559
# 2  12.26481   7.45645   2.99652
# 3   2.30437   1.46386  13.21820
# 4   9.05547   4.06949   7.37980
#
# [5 rows x 39 columns]

# %%
df_cluster.set_index("item", inplace = True)

# %%
df_cluster.head()
# Out:
#                   item_exhibition_days  days_with_purchases  \
# item
# ACCESORIES_1_001                  1013                  973
# ACCESORIES_1_002                  1877                 1619
# ACCESORIES_1_003                   807                  597
# ACCESORIES_1_004                  1912                 1900
# ACCESORIES_1_005                  1815                 1765
#
#                   purchase_to_exhib_ratio  units    revenue  \
# item
# ACCESORIES_1_001                  0.96051   4093   45037.55
# ACCESORIES_1_002                  0.86255   5059   26676.13
# ACCESORIES_1_003                  0.73978   1435    5652.09
# ACCESORIES_1_004                  0.99372  39143  235209.81
# ACCESORIES_1_005                  0.97245  14621   55555.94
#
#                   initial_sell_price  first_discount  \
# item
# ACCESORIES_1_001               12.74         0.13736
# ACCESORIES_1_002                5.28         0.25189
# ACCESORIES_1_003                7.94         0.00000
# ACCESORIES_1_004                6.17         0.00000
# ACCESORIES_1_005                4.10         0.09091
#
#                   days_until_first_discount  discount_on_date_days  \
# item
# ACCESORIES_1_001                         -1                   2589
# ACCESORIES_1_002                       1290                     11
# ACCESORIES_1_003                        801                   2729
# ACCESORIES_1_004                       1906                   1039
# ACCESORIES_1_005                        150                   1573
#
#                   week_sales_%  ...  BOS_1_%   BOS_2_%   BOS_3_%   NYC_1_%  \
# item                            ...
# ACCESORIES_1_001      66.72367  ...  6.35231   9.82165   9.40630  14.65917
# ACCESORIES_1_002      64.87448  ...  4.34869   5.93003   7.07650   9.74501
# ACCESORIES_1_003      62.09059  ...  6.89895   7.03833  12.40418  20.06969
# ACCESORIES_1_004      64.06509  ...  7.53136   9.09997   8.10873   8.39997
# ACCESORIES_1_005      64.09274  ...  7.68757  13.78839   6.85316  12.64619
#
#                    NYC_2_%   NYC_3_%   NYC_4_%   PHI_1_%   PHI_2_%   PHI_3_%
# item
# ACCESORIES_1_001  13.24212  18.51942  15.51429   4.34889   2.80968   5.32617
# ACCESORIES_1_002   6.48349   8.93457   6.38466  22.59340  15.41807  13.08559
# ACCESORIES_1_003  10.10453   9.54704  11.21951  12.26481   7.45645   2.99652
# ACCESORIES_1_004  19.14519  26.67654   4.05181   2.30437   1.46386  13.21820
# ACCESORIES_1_005  13.94569  18.21353   6.36071   9.05547   4.06949   7.37980
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Selección de las variables

# %%
columns_1 = df_cluster.columns.to_list()
columns_1
# Out:
# ['item_exhibition_days',
#  'days_with_purchases',
#  'purchase_to_exhib_ratio',
#  'units',
#  'revenue',
#  'initial_sell_price',
#  'first_discount',
#  'days_until_first_discount',
#  'discount_on_date_days',
#  'week_sales_%',
#  'weekend_sales_%',
#  'summer_sales_%',
#  'christmas_sales_%',
#  'event_sales_%',
#  'event_SuperBowl_sales_%',
#  'event_Thanksgiving_sales_%',
#  'event_Ramadan_sales_%',
#  'event_NewYear_sales_%',
#  'event_Easter_sales_%',
#  'discount_on_date_sales_%',
#  'mean_pvp',
#  'units_per_purchase',
#  'revenue_per_purchase',
#  'mean_discount',
#  '2016_vs_2015',
#  '2015_vs_2014',
#  '2014_vs_2013',
#  'category_id',
#  'BOS_1_%',
#  'BOS_2_%',
#  'BOS_3_%',
#  'NYC_1_%',
#  'NYC_2_%',
#  'NYC_3_%',
#  'NYC_4_%',
#  'PHI_1_%',
#  'PHI_2_%',
#  'PHI_3_%']

# %%
order_columns = [
    'revenue',
    'revenue_per_purchase',
    'units',
    'units_per_purchase',
    'mean_pvp',
    'initial_sell_price',
                    
    'category_id',
    'item_exhibition_days',
    'days_with_purchases',
    'purchase_to_exhib_ratio',

    'mean_discount',
    'first_discount',
    'days_until_first_discount',
    'discount_on_date_days',
    'discount_on_date_sales_%',

    'week_sales_%',
    'weekend_sales_%',
    'summer_sales_%',
    'christmas_sales_%',

    'event_sales_%',
    'event_SuperBowl_sales_%',
    'event_Thanksgiving_sales_%',
    'event_Ramadan_sales_%',
    'event_NewYear_sales_%',
    'event_Easter_sales_%',

    '2016_vs_2015',
    '2015_vs_2014',
    '2014_vs_2013',

    'BOS_1_%',
    'BOS_2_%',
    'BOS_3_%',
    'NYC_1_%',
    'NYC_2_%',
    'NYC_3_%',
    'NYC_4_%',
    'PHI_1_%',
    'PHI_2_%',
    'PHI_3_%'
    ]

# %%
df_cluster = df_cluster.reindex(columns=order_columns)
df_cluster.head()
# Out:
#                     revenue  revenue_per_purchase  units  units_per_purchase  \
# item
# ACCESORIES_1_001   45037.55              46.28731   4093             4.20658
# ACCESORIES_1_002   26676.13              16.47692   5059             3.12477
# ACCESORIES_1_003    5652.09               9.46749   1435             2.40369
# ACCESORIES_1_004  235209.81             123.79464  39143            20.60158
# ACCESORIES_1_005   55555.94              31.47645  14621             8.28385
#
#                   mean_pvp  initial_sell_price  category_id  \
# item
# ACCESORIES_1_001  11.00355               12.74            0
# ACCESORIES_1_002   5.27300                5.28            0
# ACCESORIES_1_003   3.93874                7.94            0
# ACCESORIES_1_004   6.00899                6.17            0
# ACCESORIES_1_005   3.79974                4.10            0
#
#                   item_exhibition_days  days_with_purchases  \
# item
# ACCESORIES_1_001                  1013                  973
# ACCESORIES_1_002                  1877                 1619
# ACCESORIES_1_003                   807                  597
# ACCESORIES_1_004                  1912                 1900
# ACCESORIES_1_005                  1815                 1765
#
#                   purchase_to_exhib_ratio  ...  BOS_1_%   BOS_2_%   BOS_3_%  \
# item                                       ...
# ACCESORIES_1_001                  0.96051  ...  6.35231   9.82165   9.40630
# ACCESORIES_1_002                  0.86255  ...  4.34869   5.93003   7.07650
# ACCESORIES_1_003                  0.73978  ...  6.89895   7.03833  12.40418
# ACCESORIES_1_004                  0.99372  ...  7.53136   9.09997   8.10873
# ACCESORIES_1_005                  0.97245  ...  7.68757  13.78839   6.85316
#
#                    NYC_1_%   NYC_2_%   NYC_3_%   NYC_4_%   PHI_1_%   PHI_2_%  \
# item
# ACCESORIES_1_001  14.65917  13.24212  18.51942  15.51429   4.34889   2.80968
# ACCESORIES_1_002   9.74501   6.48349   8.93457   6.38466  22.59340  15.41807
# ACCESORIES_1_003  20.06969  10.10453   9.54704  11.21951  12.26481   7.45645
# ACCESORIES_1_004   8.39997  19.14519  26.67654   4.05181   2.30437   1.46386
# ACCESORIES_1_005  12.64619  13.94569  18.21353   6.36071   9.05547   4.06949
#
#                    PHI_3_%
# item
# ACCESORIES_1_001   5.32617
# ACCESORIES_1_002  13.08559
# ACCESORIES_1_003   2.99652
# ACCESORIES_1_004  13.21820
# ACCESORIES_1_005   7.37980
#
# [5 rows x 38 columns]

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3049 entries, ACCESORIES_1_001 to SUPERMARKET_3_827
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   revenue                     3049 non-null   float64
#  1   revenue_per_purchase        3049 non-null   float64
#  2   units                       3049 non-null   int64
#  3   units_per_purchase          3049 non-null   float64
#  4   mean_pvp                    3049 non-null   float64
#  5   initial_sell_price          3049 non-null   float64
#  6   category_id                 3049 non-null   int64
#  7   item_exhibition_days        3049 non-null   int64
#  8   days_with_purchases         3049 non-null   int64
#  9   purchase_to_exhib_ratio     3049 non-null   float64
#  10  mean_discount               3049 non-null   float64
#  11  first_discount              3049 non-null   float64
#  12  days_until_first_discount   3049 non-null   int64
#  13  discount_on_date_days       3049 non-null   int64
#  14  discount_on_date_sales_%    3049 non-null   float64
#  15  week_sales_%                3049 non-null   float64
#  16  weekend_sales_%             3049 non-null   float64
#  17  summer_sales_%              3049 non-null   float64
#  18  christmas_sales_%           3049 non-null   float64
#  19  event_sales_%               3049 non-null   float64
#  20  event_SuperBowl_sales_%     3049 non-null   float64
#  21  event_Thanksgiving_sales_%  3049 non-null   float64
#  22  event_Ramadan_sales_%       3049 non-null   float64
#  23  event_NewYear_sales_%       3049 non-null   float64
#  24  event_Easter_sales_%        3049 non-null   float64
#  25  2016_vs_2015                3049 non-null   float64
#  26  2015_vs_2014                3049 non-null   float64
#  27  2014_vs_2013                3049 non-null   float64
#  28  BOS_1_%                     3049 non-null   float64
#  29  BOS_2_%                     3049 non-null   float64
#  30  BOS_3_%                     3049 non-null   float64
#  31  NYC_1_%                     3049 non-null   float64
#  32  NYC_2_%                     3049 non-null   float64
#  33  NYC_3_%                     3049 non-null   float64
#  34  NYC_4_%                     3049 non-null   float64
#  35  PHI_1_%                     3049 non-null   float64
#  36  PHI_2_%                     3049 non-null   float64
#  37  PHI_3_%                     3049 non-null   float64
# dtypes: float64(32), int64(6)
# memory usage: 929.0+ KB

# %% [markdown]
# ### Pipeline - Clusters por Item

# %% [markdown]
# Llegamos a este punto tenemos todo listo para construir nuestro pipeline.
#
# Los pasos que va a realizar son:
#
# 1. Dado que en el primer paso, nos devuelve un array, usamos nuestro propio Transformer para convertir a DataFrame.
#
# 2. Estandarizamos los valores, usando un Scaler personalizado para eliminar la influencia de los outliers.
#
# 3. Hacemos un fit con KMeans para calcular la inertia de los grupos (la dispersión de los datos al centroide).
#
# Técnica del ***Elbow Curve***: todo esto lo hacemos en una loop porque queremos ver cuando hay un cambio brusco en la inertia. Dicho de otro modo **aumentar más el número de centroides no nos sale a cuenta porque la ganacia marginal es muy pequeña.**

# %%
# De todas estas variables, vamos a seleccionar aquellas con las que vamso a segmentar los items:
selected_columns = [
                    #'revenue',
                    'revenue_per_purchase',
                    #'units',
                    'units_per_purchase',
                    'mean_pvp',
                    #'initial_sell_price',

                    #'category_id',
                    #'item_exhibition_days',
                    #'days_with_purchases',
                    'purchase_to_exhib_ratio',

                    'mean_discount',
                    #'first_discount',
                    #'days_until_first_discount',
                    #'discount_on_date_days',
                    #'discount_on_date_sales_%',

                    #'week_sales_%',
                    #'weekend_sales_%',
                    #'summer_sales_%',
                    #'christmas_sales_%',
                    #'event_sales_%',
                    #'event_SuperBowl_sales_%',
                    #'event_Thanksgiving_sales_%',
                    #'event_Ramadan_sales_%',
                    #'event_NewYear_sales_%',
                    #'event_Easter_sales_%',

                    '2016_vs_2015',
                    '2015_vs_2014',
                    '2014_vs_2013',

                    #'BOS_1_%',
                    #'BOS_2_%',
                    #'BOS_3_%',
                    #'NYC_1_%',
                    #'NYC_2_%',
                    #'NYC_3_%',
                    #'NYC_4_%',
                    #'PHI_1_%',
                    #'PHI_2_%',
                    #'PHI_3_%'
                    ]

# %%
class ArrayToDataFrame(BaseEstimator, TransformerMixin):
    '''
    Clase que transforma un array en un DataFrame.
    Necesita como parámetros el nombre de las columnas y el índice.
    '''
    
    def __init__(self, columns, index = None):
        self.columns = columns
        self.index = index
        
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        
        if self.index != None:
            df = pd.DataFrame(X, columns = self.columns, index = self.index)
            
        else:
            df = pd.DataFrame(X, columns = self.columns)
            
        return df

# %%
class OutlierFilter(BaseEstimator, TransformerMixin):
    '''
    Clase que filtra los outliers utilizando np.quantile()
    Los cuantiles a filtrar así como las columnas a filtrar son los parámetros de la clase.
    '''
    
    def __init__(self, q, col_to_filter):
        self.q = q
        self.col_to_filter = col_to_filter
        
    def fit(self, X, y = None):
        return self
    
    def transform(self, X, y = None):
        '''
        El método considera outlier a aquel item que es outlier en TODAS las columnas que le pasas.
        '''
        
        # lista vacía
        criteria_list = []
        
        # agregamos a la lista los items que son outliers
        for col in self.col_to_filter:
            criteria = X[col] <= np.quantile(X[col], q = self.q)
            criteria_list.append(criteria)
            
        # si hay más de 1 columna
        if len(self.col_to_filter) > 1:
            
            # creamos el criterio global: es decir outlier en todas las columnas
            global_criteria = criteria_list[0]
            
            for criteria in criteria_list[1:]:
                global_criteria = global_criteria & criteria
                
        else:
            global_criteria = criteria_list[0]
            
        # filtramos nuestra dataframe
        X = X[global_criteria]
        
        # guardamos el índice como parámetro de la clase porque en caso contrario lo perderíamos.
        self.index = X.index
        
        return X

# %%
def scale_and_fit(df):
    columns = list(df.columns)
    index = list(df.index)
    pipe = Pipeline(steps = [
        ("Imputer", KNNImputer()), 
        ("ArrayToDataFrame", ArrayToDataFrame(columns = columns, index = index)),
        ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = selected_columns)),
        ("StandardScaler", StandardScaler())
        ])
    df_scaled_transformed = pipe.fit_transform(df)
    return df_scaled_transformed

# %%
## Elvow curve 
def plot_elbow_curve_and_find_optimal_k(df_scaled_transformed, threshold=0.05): #Threshold: 5% de bajada del error
    sse = {}
    for k in range(2, 20):
        print(f"Fitting pipe with {k} clusters")
        clustering_model = KMeans(n_clusters = k)
        clustering_model.fit(df_scaled_transformed)
        sse[k] = clustering_model.inertia_
    # Elbow curve
    plt.figure(figsize = (16, 8))
    plt.plot(list(sse.keys()), list(sse.values()), label = "Inertia/dispersión de los clústers")
    plt.title("Variación de la dispersión de los clústers en función de la k")
    plt.show()
    
    # Optimal k
    keys = list(sse.keys())
    vals = list(sse.values())
    
    for i in range(1, len(keys)):
        ratio = (vals[i-1] - vals[i]) / vals[i-1]
        if ratio < threshold:
            print("El número óptimo de clusters es ", keys[i-1])
            return keys[i-1]
    print("El número óptimo de clusters es ", keys[-1])
    return keys[-1]

# %%
## Segmentación de los productos con la k adecuada
def cluster_and_predict(df, N_CLUSTERS):
    columns = list(df.columns)
    index = list(df.index)
    pipe = Pipeline(steps = [
        ("Imputer", KNNImputer()), 
        ("ArrayToDataFrame", ArrayToDataFrame(columns, index = index)),
        ("OutlierFilter", OutlierFilter(q = 0.99, col_to_filter = selected_columns)),
        ("StandardScaler", StandardScaler()),
        ("Clustering", KMeans(n_clusters = N_CLUSTERS))
        ])
    pipe.fit(df)
    return pipe

# %%
df = df_cluster.copy()

# %%
df.shape
# Out:
# (3049, 38)

# %%
df.head()
# Out:
#                     revenue  revenue_per_purchase  units  units_per_purchase  \
# item
# ACCESORIES_1_001   45037.55              46.28731   4093             4.20658
# ACCESORIES_1_002   26676.13              16.47692   5059             3.12477
# ACCESORIES_1_003    5652.09               9.46749   1435             2.40369
# ACCESORIES_1_004  235209.81             123.79464  39143            20.60158
# ACCESORIES_1_005   55555.94              31.47645  14621             8.28385
#
#                   mean_pvp  initial_sell_price  category_id  \
# item
# ACCESORIES_1_001  11.00355               12.74            0
# ACCESORIES_1_002   5.27300                5.28            0
# ACCESORIES_1_003   3.93874                7.94            0
# ACCESORIES_1_004   6.00899                6.17            0
# ACCESORIES_1_005   3.79974                4.10            0
#
#                   item_exhibition_days  days_with_purchases  \
# item
# ACCESORIES_1_001                  1013                  973
# ACCESORIES_1_002                  1877                 1619
# ACCESORIES_1_003                   807                  597
# ACCESORIES_1_004                  1912                 1900
# ACCESORIES_1_005                  1815                 1765
#
#                   purchase_to_exhib_ratio  ...  BOS_1_%   BOS_2_%   BOS_3_%  \
# item                                       ...
# ACCESORIES_1_001                  0.96051  ...  6.35231   9.82165   9.40630
# ACCESORIES_1_002                  0.86255  ...  4.34869   5.93003   7.07650
# ACCESORIES_1_003                  0.73978  ...  6.89895   7.03833  12.40418
# ACCESORIES_1_004                  0.99372  ...  7.53136   9.09997   8.10873
# ACCESORIES_1_005                  0.97245  ...  7.68757  13.78839   6.85316
#
#                    NYC_1_%   NYC_2_%   NYC_3_%   NYC_4_%   PHI_1_%   PHI_2_%  \
# item
# ACCESORIES_1_001  14.65917  13.24212  18.51942  15.51429   4.34889   2.80968
# ACCESORIES_1_002   9.74501   6.48349   8.93457   6.38466  22.59340  15.41807
# ACCESORIES_1_003  20.06969  10.10453   9.54704  11.21951  12.26481   7.45645
# ACCESORIES_1_004   8.39997  19.14519  26.67654   4.05181   2.30437   1.46386
# ACCESORIES_1_005  12.64619  13.94569  18.21353   6.36071   9.05547   4.06949
#
#                    PHI_3_%
# item
# ACCESORIES_1_001   5.32617
# ACCESORIES_1_002  13.08559
# ACCESORIES_1_003   2.99652
# ACCESORIES_1_004  13.21820
# ACCESORIES_1_005   7.37980
#
# [5 rows x 38 columns]

# %%
df_scaled = scale_and_fit(df)

# %%
## Elvow curve
plot_elbow_curve_and_find_optimal_k(df_scaled)
# Out:
# Fitting pipe with 2 clusters
# Fitting pipe with 3 clusters
# Fitting pipe with 4 clusters
# Fitting pipe with 5 clusters
# Fitting pipe with 6 clusters
# Fitting pipe with 7 clusters
# Fitting pipe with 8 clusters
# Fitting pipe with 9 clusters
# Fitting pipe with 10 clusters
# Fitting pipe with 11 clusters
# Fitting pipe with 12 clusters
# Fitting pipe with 13 clusters
# Fitting pipe with 14 clusters
# Fitting pipe with 15 clusters
# Fitting pipe with 16 clusters
# Fitting pipe with 17 clusters
# Fitting pipe with 18 clusters
# Fitting pipe with 19 clusters
# El número óptimo de clusters es  4
# 4

# %%
N_CLUSTERS = 4

# %%
## Segmentación de los productos con la k adecuada
pipe = cluster_and_predict(df, N_CLUSTERS)
## Pipe (4/5):
X_processed = pipe[:2].transform(df) #sin escalar
X_scaled = pipe["StandardScaler"].transform(X_processed) #escalado
## Pipe (5/5): hacemos el predict, en este caso tendremos para cada item su centroide/clúster
labels = pipe["Clustering"].predict(X_scaled)
# le asignamos al DataFrame procesado el clúster.
# si lo hacemos al df escalado será más díficil de interpretar los resultados porque los números están escalados
X_processed["cluster"] = labels

# %%
# Graficar las relaciones entre las variables:
sns.pairplot(X_processed, vars = selected_columns, hue = 'cluster')

# %%
X_cluster = X_processed["cluster"]
X_cluster
# Out:
# ACCESORIES_1_001     2
# ACCESORIES_1_002     3
# ACCESORIES_1_003     2
# ACCESORIES_1_004     1
# ACCESORIES_1_005     2
#                     ..
# SUPERMARKET_3_823    2
# SUPERMARKET_3_824    2
# SUPERMARKET_3_825    2
# SUPERMARKET_3_826    3
# SUPERMARKET_3_827    3
# Name: cluster, Length: 3049, dtype: int32

# %%
X_cluster.value_counts()
# Out:
# 2    1042
# 3     827
# 1     819
# 0     361
# Name: cluster, dtype: int64

# %% [markdown]
# #### Ficha de los productos

# %% [markdown]
# El último paso, usa vez que tenemos hecha nuestra segmentación completa es crear una ***ficha resumen*** de cada grupo con las principales variables de negocio o con aquellas que no se han utilizado en la segmentación para hacer un seguimiento periódico de los grupos o para enviar como documento al resto de los departamentos de la empresa.

# %%
ficha_df = pd.DataFrame()

# %%
for col in selected_columns:
    resumen_data = X_processed[["cluster", col]].groupby("cluster").describe().T[1:]
    ficha_df = ficha_df.append(resumen_data)

# %%
resumen_data
# Out:
# cluster                    0          1          2            3
# 2014_vs_2013 mean   0.066720   0.165199   0.146958    10.050785
#              std    0.825777   1.581426   1.388943    96.848484
#              min   -0.929590  -1.000000  -0.919720    -0.997430
#              25%   -0.217680  -0.164530  -0.223765     0.000000
#              50%   -0.073110  -0.041390  -0.068230     0.000000
#              75%    0.098740   0.134480   0.142512     0.535015
#              max   11.152320  32.200000  30.428570  1978.000000

# %%
# generamos nuestro multiindex
out_index = [
    #'Revenue',
    'Revenue',
    #'Unidades',
    "Unidades",
    "Precio",
    #"Precio_inicial",

    #"Categoría",
    #"Rendimiento de ventas",
    #"Rendimiento de ventas",
    "Rendimiento de ventas",

    "Descuento",
    #"Descuento",
    #"Descuento",
    #"Descuento",
    #"Descuento",

    #"Campaña",
    #"Campaña",
    #"Campaña",
    #"Campaña",
    #"Campaña",
    #"Campaña",
    #"Campaña",
    #"Campaña",
    #"Campaña",
    #"Campaña",

    "Crecimiento",
    "Crecimiento",
    "Crecimiento",

    #"Tienda",
    #"Tienda",
    #"Tienda",
    #"Tienda",
    #"Tienda",
    #"Tienda",
    #"Tienda",
    #"Tienda",
    #"Tienda",
    #"Tienda",
    ]

inner_index = selected_columns

estadisticos = ["Media", "Desviación", "Mínimo", "Perc. 25", "Perc. 50", "Perc. 75", "Máximo"]

new_multi_index = []

for oi, ii, in zip(out_index, inner_index):
    for es in estadisticos:
        new_multi_index.append((oi, ii, es))

# %%
def generate_multiindex(list_of_tuples, names):
    return pd.MultiIndex.from_tuples(list_of_tuples, names = names)

# %%
names = ["Grupo Indicadores", "Indicador", "Estadístico"]
index_ficha = generate_multiindex(new_multi_index, names)
ficha_df.set_index(index_ficha, inplace = True)

# %%
tamaño_clusters = X_processed.groupby("cluster").size().to_frame().T
tamaño_clusters.set_index(generate_multiindex([("General", "Clúster", "Tamaño")] , names), inplace = True)

# %%
ficha_df = tamaño_clusters.append(ficha_df)

# %%
ficha_df.style.background_gradient(cmap = 'Blues', axis = 1)
# Out:
# <style type="text/css">
# #T_4d076_row0_col0, #T_4d076_row1_col0, #T_4d076_row2_col0, #T_4d076_row3_col0, #T_4d076_row4_col0, #T_4d076_row5_col0, #T_4d076_row6_col0, #T_4d076_row7_col0, #T_4d076_row8_col0, #T_4d076_row9_col0, #T_4d076_row10_col0, #T_4d076_row11_col0, #T_4d076_row12_col0, #T_4d076_row13_col0, #T_4d076_row14_col1, #T_4d076_row15_col1, #T_4d076_row16_col1, #T_4d076_row17_col1, #T_4d076_row18_col1, #T_4d076_row19_col1, #T_4d076_row20_col1, #T_4d076_row21_col0, #T_4d076_row22_col1, #T_4d076_row23_col0, #T_4d076_row24_col0, #T_4d076_row25_col0, #T_4d076_row26_col0, #T_4d076_row27_col0, #T_4d076_row27_col3, #T_4d076_row28_col2, #T_4d076_row29_col2, #T_4d076_row31_col2, #T_4d076_row32_col2, #T_4d076_row33_col2, #T_4d076_row34_col1, #T_4d076_row35_col3, #T_4d076_row36_col3, #T_4d076_row37_col3, #T_4d076_row38_col3, #T_4d076_row39_col3, #T_4d076_row40_col3, #T_4d076_row41_col3, #T_4d076_row42_col3, #T_4d076_row43_col3, #T_4d076_row44_col0, #T_4d076_row45_col3, #T_4d076_row46_col3, #T_4d076_row47_col3, #T_4d076_row48_col3, #T_4d076_row49_col3, #T_4d076_row50_col3, #T_4d076_row51_col2, #T_4d076_row52_col3, #T_4d076_row53_col3, #T_4d076_row54_col3, #T_4d076_row55_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4d076_row0_col1, #T_4d076_row13_col3, #T_4d076_row14_col2, #T_4d076_row24_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_4d076_row0_col2, #T_4d076_row0_col3, #T_4d076_row1_col2, #T_4d076_row2_col3, #T_4d076_row3_col3, #T_4d076_row4_col3, #T_4d076_row5_col3, #T_4d076_row6_col2, #T_4d076_row7_col1, #T_4d076_row8_col1, #T_4d076_row9_col2, #T_4d076_row10_col1, #T_4d076_row11_col1, #T_4d076_row12_col1, #T_4d076_row13_col1, #T_4d076_row14_col0, #T_4d076_row15_col2, #T_4d076_row16_col0, #T_4d076_row17_col0, #T_4d076_row18_col0, #T_4d076_row19_col0, #T_4d076_row20_col2, #T_4d076_row21_col1, #T_4d076_row22_col0, #T_4d076_row23_col3, #T_4d076_row24_col1, #T_4d076_row25_col1, #T_4d076_row26_col1, #T_4d076_row27_col1, #T_4d076_row28_col3, #T_4d076_row29_col3, #T_4d076_row30_col0, #T_4d076_row30_col1, #T_4d076_row30_col2, #T_4d076_row30_col3, #T_4d076_row31_col3, #T_4d076_row32_col3, #T_4d076_row33_col3, #T_4d076_row34_col3, #T_4d076_row35_col0, #T_4d076_row35_col1, #T_4d076_row35_col2, #T_4d076_row36_col0, #T_4d076_row36_col1, #T_4d076_row37_col0, #T_4d076_row37_col1, #T_4d076_row38_col1, #T_4d076_row39_col0, #T_4d076_row40_col1, #T_4d076_row41_col0, #T_4d076_row41_col1, #T_4d076_row42_col1, #T_4d076_row43_col1, #T_4d076_row43_col2, #T_4d076_row44_col2, #T_4d076_row45_col0, #T_4d076_row46_col0, #T_4d076_row47_col0, #T_4d076_row48_col1, #T_4d076_row48_col2, #T_4d076_row49_col0, #T_4d076_row50_col0, #T_4d076_row51_col1, #T_4d076_row52_col2, #T_4d076_row53_col0, #T_4d076_row54_col0, #T_4d076_row55_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4d076_row1_col1 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_4d076_row1_col3, #T_4d076_row3_col2, #T_4d076_row4_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_4d076_row2_col1, #T_4d076_row10_col3, #T_4d076_row13_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_4d076_row2_col2, #T_4d076_row51_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_4d076_row3_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_4d076_row4_col2, #T_4d076_row11_col3, #T_4d076_row39_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_4d076_row5_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_4d076_row5_col2, #T_4d076_row36_col2, #T_4d076_row48_col0, #T_4d076_row50_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_4d076_row6_col1, #T_4d076_row11_col2, #T_4d076_row21_col3, #T_4d076_row28_col1, #T_4d076_row40_col0, #T_4d076_row54_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_4d076_row6_col3, #T_4d076_row16_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_4d076_row7_col2, #T_4d076_row10_col2, #T_4d076_row12_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_4d076_row7_col3, #T_4d076_row12_col3, #T_4d076_row47_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_4d076_row8_col2, #T_4d076_row8_col3, #T_4d076_row53_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_4d076_row9_col1, #T_4d076_row52_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_4d076_row9_col3 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_4d076_row14_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_4d076_row15_col0, #T_4d076_row26_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_4d076_row15_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_4d076_row16_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_4d076_row17_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_4d076_row17_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_4d076_row18_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_4d076_row18_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_4d076_row19_col2, #T_4d076_row25_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_4d076_row19_col3, #T_4d076_row29_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_4d076_row20_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_4d076_row20_col3 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_4d076_row21_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_4d076_row22_col2 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_4d076_row22_col3 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_4d076_row23_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_4d076_row23_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_4d076_row24_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_4d076_row25_col2 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_4d076_row26_col3 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_4d076_row27_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_4d076_row28_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_4d076_row29_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_4d076_row31_col0, #T_4d076_row52_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_4d076_row31_col1, #T_4d076_row42_col0, #T_4d076_row42_col2, #T_4d076_row43_col0, #T_4d076_row49_col1, #T_4d076_row49_col2, #T_4d076_row50_col1, #T_4d076_row55_col1, #T_4d076_row55_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_4d076_row32_col0 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_4d076_row32_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_4d076_row33_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_4d076_row33_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_4d076_row34_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_4d076_row34_col2 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_4d076_row37_col2, #T_4d076_row44_col3 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_4d076_row38_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_4d076_row38_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_4d076_row39_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_4d076_row40_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_4d076_row41_col2, #T_4d076_row47_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_4d076_row44_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_4d076_row45_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_4d076_row45_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_4d076_row46_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_4d076_row46_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_4d076_row51_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_4d076_row53_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_4d076_row54_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_4d076_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >c

# %%
ficha_df = ficha_df.rename(columns = {
    0 : "Best sellers",
    1 : "Gama Premium",
    2 : "On Sale",
    3 : "Rising",
})

# %%
ficha_df.to_csv("E:/Capstone-Retail/data_dsmarket/task_2_clustering/item_clusters_4_report_230718_reduced.csv") #Marina Windows

# %%
X_cluster["cluster"] = X_cluster["cluster"].replace({
    0: "Best sellers",
    1: "Premium",
    2: "On Sale",
    3: "Rising"
})

# %%
X_cluster.head()
# Out:
#                item  cluster
# 0  ACCESORIES_1_001  On Sale
# 1  ACCESORIES_1_002   Rising
# 2  ACCESORIES_1_003  On Sale
# 3  ACCESORIES_1_004  Premium
# 4  ACCESORIES_1_005  On Sale

# %%
X_cluster["cluster"].value_counts()
# Out:
# On Sale         1042
# Rising           827
# Premium          819
# Best sellers     361
# Name: cluster, dtype: int64

# %%
X_cluster.to_csv("E:/Capstone-Retail/data_dsmarket/task_2_clustering/item_clusters_4_230718_reduced.csv", index=False) #Marina Windows
